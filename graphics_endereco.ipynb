# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# Novos valores para Textract e Tesseract + Paddle
textract_values = [
    0.484304932735426, 0.6838235294117647, 0.42574257425742573, 0.6918238993710691,
    0.6328125, 0.543046357615894, 0.47985347985347987, 0.488, 0.5978835978835979,
    0.6148148148148148, 0.6265060240963856, 0.6591928251121076, 0.653160453808752,
    0.38461538461538464, 0.7073170731707317, 0.45564516129032256, 0.7358490566037735,
    0.6064139941690962, 0.6809815950920245, 0.78125, 0.5903225806451613,
    0.6079295154185022, 0.6239316239316239, 0.5513196480938416, 0.6267605633802817,
    0.5892857142857143, 0.5896103896103896, 0.4591439688715953, 0.6862745098039216,
    0.621438263229308, 0.510989010989011, 0.6205357142857143, 0.2967741935483871,
    0.5779816513761468, 0.6375, 0.32432432432432434, 0.5864197530864198,
    0.2980132450331126, 0.5714285714285714, 0.7777777777777778, 0.601010101010101,
    0.6788990825688074, 0.5623100303951368, 0.49122807017543857, 0.6291793313069909,
    0.3275862068965517, 0.6114649681528662, 0.5903614457831325, 0.6077348066298343,
    0.6297786720321932, 0.5526315789473685, 0.5367647058823529, 0.5660377358490566,
    0.5686274509803921, 0.6961325966850829
]

tesseract_values = [
    0.3252032520325203, 0.5126050420168067, 0.4108333333333334, 0.5508474576271186,
    0.5675675675675675, 0.4634146341463415, 0.3111111111111111, 0.45569620253164556,
    0.45535714285714285, 0.5673076923076923, 0.4727272727272727, 0.6085106382978723,
    0.5619967793880838, 0.4714285714285714, 0.5154639175257731, 0.4101123595505618,
    0.7075471698113207, 0.5384615384615384, 0.5941176470588235, 0.7699115044247787,
    0.5358490566037736, 0.5965665236051502, 0.49375, 0.5449101796407185,
    0.5696969696969697, 0.5688073394495413, 0.5145631067961165, 0.32413793103448274,
    0.5232558139534884, 0.5037220843672456, 0.423728813559322, 0.6197916666666666,
    0.18181818181818182, 0.5795454545454546, 0.44086021505376344, 0.2727272727272727,
    0.26492537313432835, 0.3939393939393939, 0.4426229508196721, 0.0,
    0.40053763440860213, 0.5601851851851852, 0.4915254237288136, 0.5307692307692308,
    0.5789473684210527, 0.4, 0.6, 0.48792270531400966, 0.4413793103448276,
    0.642369020501139, 0.5126050420168067, 0.3384615384615385, 0.42857142857142855,
    0.5061728395061729, 0.4453125
]

# Criar os índices aproximados dos documentos
documents = list(range(1, 56))

# Criar o gráfico
plt.figure(figsize=(12, 6))
plt.plot(documents, textract_values, label='Textract', color='blue', marker='o')
plt.plot(documents, tesseract_values, label='Tesseract + Paddle', color='orange', marker='o')

# Configurar o gráfico
plt.title('Comparação entre Textract e Tesseract')
plt.xlabel('Número de Documentos (1 a 55)')
plt.ylabel('Percentual de Palavras Válidas')

# Exibir apenas rótulos espaçados a cada 5 documentos
plt.xticks(documents[::5])

# Rotacionar rótulos para 45 graus


plt.legend()
plt.grid()

# Exibir o gráfico
plt.show()
