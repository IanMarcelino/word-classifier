# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt


textract_values = [
    0.47474747474747475, 0.4, 0.5098039215686274, 0.296551724137931, 0.24096385542168675,
    0.46153846153846156, 0.39914163090128757, 0.45544554455445546, 0.45588235294117646,
    0.45161290322580644, 0.36936936936936937, 0.43333333333333335, 0.3781094527363184,
    0.4485981308411215, 0.46875, 0.45454545454545453, 0.4186046511627907, 0.3615023474178404,
    0.3225806451612903, 0.3907563025210084, 0.4, 0.49333333333333335, 0.42857142857142855,
    0.4857142857142857, 0.4823529411764706, 0.4818181818181818, 0.5402298850574713, 0.0,
    0.41025641025641024, 0.45555555555555555
]

tesseract_values = [
    0.4647887323943662, 0.4, 0.3614457831325301, 0.41007194244604317, 0.21666666666666667,
    0.36, 0.3674418604651163, 0.35714285714285715, 0.43137254901960786, 0.379746835443038,
    0.4594594594594595, 0.3373493975903614, 0.2982456140350877, 0.4418604651162791, 0.4,
    0.3333333333333333, 0.4090909090909091, 0.2926829268292683, 0.2896551724137931,
    0.36086956521739133, 0.3191489361702128, 0.3877551020408163, 0.2809917355371901,
    0.3711340206185567, 0.5, 0.4342105263157895, 0.10714285714285714, 0.0967741935483871,
    0.3387096774193548, 0.3835616438356164
]


documents = list(range(1, 31))


plt.figure(figsize=(12, 6))
plt.plot(documents, textract_values, label='Textract', color='blue', marker='o')
plt.plot(documents, tesseract_values, label='Tesseract + Paddle', color='orange', marker='o')


plt.title('Comparação entre Textract e Tesseract')
plt.xlabel('Número de Documentos (1 a 30)')
plt.ylabel('Percentual de Palavras Válidas')
plt.xticks(documents)
plt.legend()
plt.grid()


plt.show()
