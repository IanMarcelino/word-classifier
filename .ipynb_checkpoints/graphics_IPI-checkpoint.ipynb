# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# Novos valores para Textract e Tesseract + Paddle
textract_values = [
    0.7321428571428571, 0.7244444444444444, 0.7276785714285714, 0.7219730941704036,
    0.7232142857142857, 0.726457399103139, 0.7232142857142857, 0.7085201793721974,
    0.7288888888888889, 0.7288888888888889, 0.7309417040358744, 0.726457399103139,
    0.726457399103139, 0.7276785714285714, 0.726457399103139, 0.7288888888888889,
    0.7174887892376681, 0.726457399103139, 0.726457399103139, 0.7276785714285714,
    0.726457399103139, 0.7333333333333333, 0.7276785714285714, 0.7309417040358744,
    0.7377777777777778, 0.7219730941704036, 0.7219730941704036, 0.726457399103139,
    0.7276785714285714, 0.7377777777777778, 0.7232142857142857, 0.7309417040358744,
    0.726457399103139, 0.7174887892376681, 0.726457399103139, 0.7232142857142857,
    0.7354260089686099, 0.7309417040358744, 0.7276785714285714, 0.7321428571428571,
    0.726457399103139, 0.7276785714285714, 0.7244444444444444, 0.7276785714285714,
    0.726457399103139, 0.7321428571428571, 0.7321428571428571, 0.7232142857142857,
    0.7309417040358744, 0.7309417040358744, 0.726457399103139, 0.7232142857142857,
    0.7354260089686099, 0.7297297297297297, 0.7276785714285714
]

tesseract_values = [
    0.5327510917030568, 0.5301724137931034, 0.5324675324675324, 0.5347826086956522,
    0.5391304347826087, 0.5283842794759825, 0.7232142857142857, 0.5431034482758621,
    0.5374449339207048, 0.5434782608695652, 0.5391304347826087, 0.5221238938053098,
    0.5411255411255411, 0.5391304347826087, 0.5353982300884956, 0.5223214285714286,
    0.5304347826086957, 0.5283842794759825, 0.5324675324675324, 0.5263157894736842,
    0.5407725321888412, 0.5411255411255411, 0.5434782608695652, 0.5431034482758621,
    0.5347826086956522, 0.5347826086956522, 0.5327510917030568, 0.5309734513274337,
    0.5431034482758621, 0.5344827586206896, 0.5434782608695652, 0.5391304347826087,
    0.5244444444444445, 0.5333333333333333, 0.5281385281385281, 0.5391304347826087,
    0.537117903930131, 0.5307017543859649, 0.5307017543859649, 0.5307017543859649,
    0.5286343612334802, 0.5286343612334802, 0.5307017543859649, 0.5309734513274337,
    0.537117903930131, 0.5374449339207048, 0.5283842794759825, 0.537117903930131,
    0.5367965367965368, 0.5304347826086957, 0.5281385281385281, 0.537117903930131,
    0.5288888888888889, 0.5219298245614035, 0.5350877192982456
]

# Criar os índices aproximados dos documentos
documents = list(range(1, 56))

# Criar o gráfico
plt.figure(figsize=(12, 6))
plt.plot(documents, textract_values, label='Textract', color='blue', marker='o')
plt.plot(documents, tesseract_values, label='Tesseract + Paddle', color='orange', marker='o')

# Configurar o gráfico
plt.title('Comparação entre Textract e Tesseract + Paddle')
plt.xlabel('Número de Documentos (1 a 55)')
plt.ylabel('Percentual de Palavras Válidas')

# Exibir apenas rótulos espaçados a cada 5 documentos
plt.xticks(documents[::5])

plt.legend()
plt.grid()

# Exibir o gráfico
plt.show()
